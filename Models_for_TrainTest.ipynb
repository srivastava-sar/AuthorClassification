# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn import cluster, datasets, mixture
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import cluster, datasets, mixture
from sklearn import decomposition
from sklearn.mixture import GaussianMixture
from sklearn import metrics
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics



# data set
train = pd.read_table('train_tweets.txt');
train_data=train[:,1];
train_label=train[:,0];

test_data=pd.read_table('test_tweets_unlabele.txt');

# features




# linear regression
reg = LinearRegression().fit(train_data,train_label)
data_pred = reg.predict(test_data)  # make predictions

# k nearest neighbour
classifier = KNeighborsClassifier(n_neighbors=n)
classifier.fit(train_data, train_label)
y_pred = classifier.predict(test_data)


# k means
kmeans = KMeans(n_clusters=number of classes)
kmeans.fit(train+test_data)
y_kmeans = kmeans.predict(test_data)


# Gaussian Mixture model
gmm = GaussianMixture(n_components=2).fit(train+test)
labels = gmm.predict(test_data)
# number of components and models presented
n_components = np.arange(1, 25)
models = [GaussianMixture(n).fit(X) for n in n_components]
# figure plotting
fig17=plt.figure(figsize=(7, 5))
plt.plot(n_components, [m.bic(X) for m in models], label='BIC') # choosing BIC
plt.plot(n_components, [m.aic(X) for m in models], label='AIC') # choosing AIC
plt.legend(loc='best')
plt.xlabel('n_components');
plt.ylabel('Value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d13d8c260219> in <module>
#      11 # data set
#      12 train = pd.read_table('train_tweets.txt');
# ---> 13 train_data=train[:,1];
#      14 train_label=train[:,0];
#      15
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
## DNN
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import regularizers
from keras.layers import Dropout
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils


# encode class values into categorical values
encoder = LabelEncoder()
encoder.fit(train_label)
encoded_loc = encoder.transform(train_label)
# convert integers to dummy variables
dummy_label = np_utils.to_categorical(encoded_label)


# model generation with single hidden layer
model = Sequential()
model.add(Dense(32, input_dim=7, activation='relu')) # input dimension = dimension of festure vector
model.add(Dense(4, activation='softmax')) # output layer = no. of classes
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
train_histt = model.fit(train_data, dummy_loctrain, epochs=100, batch_size=32, verbose=1)

scores = model.evaluate(test_data, dummy_loctest, batch_size=32)
print('Test loss=%s'% scores[0])
print('Test accuracy=%s'% scores[1])
